# %%
#imports modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
#imports csv file
train_df = pd.read_csv(r'train.csv')
print(train_df.shape)
train_df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#calculates fill rate for columns
fill_rate = {}
for i in train_df:
    null_count = (train_df[i].isna().sum())
    frate = 100-(null_count/891)*100
    fill_rate[i]=frate

#converts fill rate from dictionary to a dataframe
fillrate_df = pd.DataFrame((fill_rate.items()), columns = ['column_name', 'fill_rate'])
fillrate_df
# Out:
#     column_name   fill_rate
# 0   PassengerId  100.000000
# 1      Survived  100.000000
# 2        Pclass  100.000000
# 3          Name  100.000000
# 4           Sex  100.000000
# 5           Age   80.134680
# 6         SibSp  100.000000
# 7         Parch  100.000000
# 8        Ticket  100.000000
# 9          Fare  100.000000
# 10        Cabin   22.895623
# 11     Embarked   99.775533

# %%
#descriptive stats for age column
train_df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#total passengers by pclass
groupedpass = train_df[['PassengerId','Pclass']].groupby(['Pclass']).count().reset_index()
groupedpass
#most number of people were travelling in third class
# Out:
#    Pclass  PassengerId
# 0       1          216
# 1       2          184
# 2       3          491

# %%
#looking at absolute survival numbers will be misleading, looking at survival rates for d/f pclass
groupedsurvd = train_df[['PassengerId','Pclass','Survived']].groupby(['Pclass']).agg(['sum', 'count']).reset_index()
groupedsurvd['survival_rate'] = (groupedsurvd['Survived']['sum']/groupedsurvd['PassengerId']['count'])*100
groupedsurvd
# Out:
#   Pclass PassengerId       Survived       survival_rate
#                  sum count      sum count
# 0      1       99705   216      136   216     62.962963
# 1      2       82056   184       87   184     47.282609
# 2      3      215625   491      119   491     24.236253

# %%
#calculates average age of men and women in diff pclass
groupedvalues = train_df[['Sex','Pclass','Age']].groupby(['Sex','Pclass']).mean().reset_index()
groupedvalues
# Out:
#       Sex  Pclass        Age
# 0  female       1  34.611765
# 1  female       2  28.722973
# 2  female       3  21.750000
# 3    male       1  41.281386
# 4    male       2  30.740707
# 5    male       3  26.507589

# %%
#plots the age of males and females by pclass
plt.figure(figsize = (10,8))
plt.plot(1,1,1)

sns.set_theme()
g = sns.barplot(data=groupedvalues, x = 'Sex', y = 'Age', hue='Pclass', ci = None, estimator = np.mean)
g.set_xlabel("Sex",fontsize=20)
g.set_ylabel("Age",fontsize=20)
g.tick_params(labelsize = 20)
#for index, row in groupedvalues.iterrows():
    #g.text(row.name, row.Age,round(row.Age,2), color = 'black', ha="right")

plt.show()

# %%
#calculates survival rates for males and females in different pclasses
grouped_survival = train_df[['Sex','Pclass','Survived']].groupby(['Sex','Pclass']).agg(['count','sum']).reset_index()
grouped_survival['survival_rate'] = (grouped_survival['Survived']['sum']/grouped_survival['Survived']['count'])*100
grouped_survival
# Out:
#       Sex Pclass Survived     survival_rate
#                     count sum
# 0  female      1       94  91     96.808511
# 1  female      2       76  70     92.105263
# 2  female      3      144  72     50.000000
# 3    male      1      122  45     36.885246
# 4    male      2      108  17     15.740741
# 5    male      3      347  47     13.544669

# %%
#plots survival rate by gender and pclass
plt.figure(figsize = (10,8))
sns.set_theme()
p = sns.barplot(data=grouped_survival, x = 'Sex', y = 'survival_rate', hue='Pclass', ci = None, estimator = np.mean)
p.set_xlabel("Sex",fontsize=20)
p.set_ylabel("Age",fontsize=20)
p.tick_params(labelsize = 20)

plt.show()

# %%
#creates a separate df for kids (below 15 years) to estimate survival rate by class and gender
bache_df = train_df[train_df['Age']<=15].reset_index()
bache_df.drop(columns = ['index'], inplace = True)
print(bache_df.shape)
bache_df.head()
# Out:
# (83, 12)
#    PassengerId  Survived  Pclass                                  Name  \
# 0            8         0       3        Palsson, Master. Gosta Leonard
# 1           10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 2           11         1       3       Sandstrom, Miss. Marguerite Rut
# 3           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 4           17         0       3                  Rice, Master. Eugene
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male   2.0      3      1   349909  21.0750   NaN        S
# 1  female  14.0      1      0   237736  30.0708   NaN        C
# 2  female   4.0      1      1  PP 9549  16.7000    G6        S
# 3  female  14.0      0      0   350406   7.8542   NaN        S
# 4    male   2.0      4      1   382652  29.1250   NaN        Q

# %%
#QC
bache_df[bache_df['Age']>15].head()
#pass
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#estimates survival rate of kids by class and gender
grouped_kids = bache_df[['Sex','Pclass','Survived']].groupby(['Sex','Pclass']).agg(['count','sum']).reset_index()
grouped_kids['survival_rate'] = (grouped_kids['Survived']['sum']/grouped_kids['Survived']['count'])*100
grouped_kids
# Out:
#       Sex Pclass Survived     survival_rate
#                     count sum
# 0  female      1        3   2     66.666667
# 1  female      2       10  10    100.000000
# 2  female      3       30  16     53.333333
# 3    male      1        3   3    100.000000
# 4    male      2        9   9    100.000000
# 5    male      3       28   9     32.142857

# %%
#we want to answer if we see random survivals or do we see survivals concentrated in families
#making a variable for total family members in train_df
train_df['total_family'] = train_df['SibSp'] + train_df['Parch']
#QC
train_df[['total_family','SibSp','Parch']].tail()
#pass
# Out:
#      total_family  SibSp  Parch
# 0               1      1      0
# 1               1      1      0
# 2               0      0      0
# 3               1      1      0
# 4               0      0      0
# ..            ...    ...    ...
# 886             0      0      0
# 887             0      0      0
# 888             3      1      2
# 889             0      0      0
# 890             0      0      0
#
# [891 rows x 3 columns]

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'total_family'],
#       dtype='object')

# %%
#seeing average of family members by pclass
sns.set()
plt.figure(figsize = (12,8))
p = sns.barplot(data=train_df, x='Pclass', y = 'total_family', ci=None, estimator = np.mean)
p.set_xlabel('Pclass', fontsize=20)
p.set_ylabel('Average_family_size',fontsize=20)
p.tick_params(labelsize = 20)
plt.show()

#so, pclass 3 had the most number of passangers, most number of families and least survival rate.

# %%
#seeing survival with total_family by pclass
sns.set()
plt.figure(figsize = (12,8))
p = sns.barplot(data=train_df, y = 'total_family', hue ='Survived', x = 'Pclass', ci = None)
p.set_xlabel('Pclass', fontsize=20)
p.set_ylabel('Average_family_size',fontsize=20)
p.tick_params(labelsize = 20)
plt.show()

#shows that for first and second pclass, those who survived had a higher family size but in third pclass,
#those who survived had a lower family size than those who died

#we now want to see if the ones who survived survived with their families intact, basically want to check if having a family increases probability 
#of survival for individual family members in d/f pclasses than those who don't have any family members.
